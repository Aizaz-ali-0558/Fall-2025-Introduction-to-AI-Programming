# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-family: 'Arial Black', Gadget, sans-serif; color: #2c3e50; font-size: 32px; text-shadow: 3px 3px 6px rgba(0, 0, 0, 0.2);">University of Engineering And Technology Peshawar</span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-family: 'Georgia', serif; color: #8e44ad; font-size: 28px;">Jalozai Campus</span>
# </div>
#
# __________________
#
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border: 2px solid #333;
#         border-radius: 15px;
#         background: #ffffff;
#         max-width: 700px;
#         box-shadow: 0 6px 15px rgba(0, 0, 0, 0.1);
#         text-align: center;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 28px;
#             color: #2c3e50;
#             text-transform: uppercase;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#         "
#     >
#         Course Title
#     </h1>
#     <h2
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 24px;
#             color: #34495e;
#             margin-top: 10px;
#         "
#     >
#         Introduction To AI Programming
#     </h2>
# </div
#
# ### 📋 <span style="color: #34495e;">Lab Information</span>
#
# - **Lab No.**: <span style="color: #e74c3c;">12</span>
# - **Lab Title**: <span style="color: #2980b9;">Execption in PYTHON </span>
#
# ### 🙋‍♂️ <span style="color: #34495e;">Submitted By</span>
#
# - **Name**: <span style="color: #2980b9;">Aizaz Ali</span>
# - **Roll No.**: <span style="color: #e74c3c;">24JZELE0558</span>
# - **Section**: <span style="color: #16a085;">B</span>
#
# ________________________

# %% [markdown]
# ________________________

# %% [markdown]
# ## **Lab Practice Task:**
# In the below task first run the code then understand the error and fix the code with exception handling.
# ### Task 1: Type Error (Add int and string)
# #### **Step 1: Run This Code**

# %%
a=10
b='5'
result=a+b
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 a=10
#       2 b='5'
# ----> 3 result=a+b
#       4 print(result)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### **Step 2: Fix the Code**
# Modify the code so the error is handled properly and a clear message is displayed instead of a crash
# Use the Following Concepts.
# -	try
# -	except
# -	TypeError

# %%
try:
    result=a+b
except TypeError as error:
    print(error)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# _________________________

# %% [markdown]
# ### **Task 2: Division by Zero**
# **Step 1: Run This Code**

# %%
x=20
y=0
Result=x/y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 x=20
#       2 y=0
# ----> 3 Result=x/y
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **What Happens**
# The program terminates due to division by zero(Understand the error).
# ### **Step 2: Fix the Code**
# Handle the exception and display a meaningful error message.
# 1. Use the Following Concepts
# -	try
# -	except
# -	ZeroDivisionError

# %%
try:
    Result=x/y
except ZeroDivisionError as ZD_error:
    print(ZD_error)
# Out:
# division by zero

# %% [markdown]
# ________________________

# %% [markdown]
# ### **Task 3: List Index Out of Range**
# **Step 1: Run This Code**

# %%
number=[10,20,30]
print(number(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 number=[10,20,30]
# ----> 2 print(number(5))
#
# TypeError: 'list' object is not callable

# %% [markdown]
# **What Happens**
# The program crashes due to invalid index access.
# ### **Step 2: Fix the Code**
# Catch the exception and display a message indicating the index is invalid.
# #### **Use the Following Concepts**
# -	try
# -	except
# -	IndexError

# %%
try:
    number(5)
except TypeError as I_error:
    print(I_error)
# Out:
# 'int' object is not callable

# %% [markdown]
# _________________

# %% [markdown]
# ### **Task 4: Logical Error Using raise**
# #### **Step 1: Run This Code**

# %%
age=-5
print('age',age)
# Out:
# age -5

# %% [markdown]
# **What Happens**
# The program runs, but the data is logically incorrect.
# ### **Step 2: Fix the Code**
# Modify the program to detect the invalid value and raise an exception manually.
# #### **Use the Following Concepts**
# -	raise
# -	Exception

# %%
age = -5
if age <1 :
    raise Exception(f"the age is invilade. ({age=})")
print(age)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 age = -5
#       2 if age <1 :
# ----> 3     raise Exception(f"the age is invilade. ({age=})")
#       4 print(age)
#
# Exception: the age is invilade. (age=-5)

# %% [markdown]
# ___________________

# %% [markdown]
# ### **Task 5: Assert Failure**
# #### **Step 1: Run This Code**

# %%
total_marks=0
assert total_marks>0
print('Total marks:',total_marks)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 total_marks=0
# ----> 2 assert total_marks>0
#       3 print('Total marks:',total_marks)
#
# AssertionError:

# %% [markdown]
# **What Happens**
# The program stops due to a failed assertion.
# #### **Step 2: Fix the Code**
# Correct the condition or handle the assertion failure properly.
# ##### **Use the Following Concepts**
# -	assert
# -	AssertionError

# %%
try:
    total_marks=int('0')
except ValueError:
    print('Error')
else:
    print('There was no error')
finally:
    print('this program is for exception error')
# Out:
# There was no error
# this program is for exception error

# %% [markdown]
# _________________

# %% [markdown]
# ### **Task 6: Assert Failure**

# %%
try:
    x=int("2")
except ValueError:
    print("Error")
else:
    print("No error occurredd")
finally:
    print('Always executed')
# Out:
# No error occurredd
# Always executed

# %% [markdown]
# **Run this code and understand by changing the code.**<br>
# the try is wrong: when the try function is wrong then except does not work.<br>
# the else block of code will run.<br>
# the finally run always.

# %% [markdown]
# ______________
