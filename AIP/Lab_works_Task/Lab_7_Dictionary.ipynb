# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-family: 'Arial Black', Gadget, sans-serif; color: #2c3e50; font-size: 32px; text-shadow: 3px 3px 6px rgba(0, 0, 0, 0.2);">University of Engineering And Technology Peshawar</span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-family: 'Georgia', serif; color: #8e44ad; font-size: 28px;">Jalozai Campus</span>
# </div>
#
# __________________
#
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border: 2px solid #333;
#         border-radius: 15px;
#         background: #ffffff;
#         max-width: 700px;
#         box-shadow: 0 6px 15px rgba(0, 0, 0, 0.1);
#         text-align: center;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 28px;
#             color: #2c3e50;
#             text-transform: uppercase;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#         "
#     >
#         Course Title
#     </h1>
#     <h2
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 24px;
#             color: #34495e;
#             margin-top: 10px;
#         "
#     >
#         Introduction To AI Programming
#     </h2>
# </div
#
# ### 📋 <span style="color: #34495e;">Lab Information</span>
#
# - **Lab No.**: <span style="color: #e74c3c;">7</span>
# - **Lab Title**: <span style="color: #2980b9;">Dictionary </span>
#
# ### 🙋‍♂️ <span style="color: #34495e;">Submitted By</span>
#
# - **Name**: <span style="color: #2980b9;">Aizaz Ali</span>
# - **Roll No.**: <span style="color: #e74c3c;">24JZELE0558</span>
# - **Section**: <span style="color: #16a085;">B</span>
#
# ---

# %% [markdown]
# _________________
# ## **Lab work tasks:**
# ___________________________

# %% [markdown]
# __________________

# %% [markdown]
# # Task 1:

# %% [markdown]
# 1)  Smart Home Energy Meter:-
#
# A smart home meter logs real-time energy usage
# >`{    "time": "18:32",`<br>
# >   `"grid_power": 720,`<br>
# >    `"solar_power": 340,`<br>
# >    `"battery_soc": 67,`<br>
# >    `"appliance_status": {"AC": "OFF", "Fridge": "ON", "Motor": "OFF"}}`<br>
# 1.	Print the "grid_power" value.
# 2.	Add a new appliance "TV": "ON" inside "appliance_status".
# 3.	Change "battery_soc" to 72.
# 4.	Check if "solar_power" exists in the dictionary.
# 5.	Delete the "Motor" key from "appliance_status".

# %%
Small_home_energy_meter={    "time": "18:32",
    "grid_power": 720,
    "solar_power": 340,
    "battery_soc": 67,
    "appliance_status": {"AC": "OFF", "Fridge": "ON", "Motor": "OFF"}}

# %%
Small_home_energy_meter['grid_power']
# Out:
# 720

# %%
Small_home_energy_meter['appliance_status']
# Out:
# {'AC': 'OFF', 'Fridge': 'ON', 'Motor': 'OFF', 'TV': 'ON'}

# %%
Small_home_energy_meter['appliance_status']['TV']='ON'
Small_home_energy_meter
# Out:
# {'time': '18:32',
#  'grid_power': 720,
#  'solar_power': 340,
#  'battery_soc': 67,
#  'appliance_status': {'AC': 'OFF', 'Fridge': 'ON', 'Motor': 'OFF', 'TV': 'ON'}}

# %%
Small_home_energy_meter['battery_soc']=72

# %%
Small_home_energy_meter['appliance_status'].pop('Motor',None)
# Out:
# 'OFF'

# %%
Small_home_energy_meter
# Out:
# {'time': '18:32',
#  'grid_power': 720,
#  'solar_power': True,
#  'battery_soc': 72,
#  'appliance_status': {'AC': 'OFF', 'Fridge': 'ON', 'TV': 'ON'}}

# %%
Small_home_energy_meter['appliance_status']['TV']='ON'

# %% [markdown]
# ___________________

# %% [markdown]
# # Task:2

# %% [markdown]
# 2)  University Student Record
#
# A system stores basic info about a student:
#
# `{  "name": "Ali Khan",`<br>
#     `"roll_no": "EE-22-045",`<br>
#     `"gpa": 3.41,`<br>
#     `"courses": ["Circuit Analysis", "Linear Algebra", "Python"],`<br>
#     `"attendance": {"Circuit Analysis": 92, "Linear Algebra": 88, "Python": 96}}`<br>
# 1.	Print the student’s GPA.
# 2.	Add a new course "Digital Logic" with attendance 90.
# 3.	Update "Linear Algebra" attendance to 91.
# 4.	Check if the key "gpa" exists.

# %%
University_student_record={  "name": "Ali Khan",
    "roll_no": "EE-22-045",
    "gpa": 3.41,
    "courses": ["Circuit Analysis", "Linear Algebra", "Python"],
    "attendance": {"Circuit Analysis": 92, "Linear Algebra": 88, "Python": 96}}

# %%
'gpa' in University_student_record
# Out:
# True

# %%
University_student_record['courses']+['Digital Logic']
# Out:
# ['Circuit Analysis', 'Linear Algebra', 'Python', 'Digital Logic']

# %%
University_student_record['attendance']['Digital Logic']='90'
University_student_record
# Out:
# {'name': 'Ali Khan',
#  'roll_no': 'EE-22-045',
#  'gpa': 3.41,
#  'courses': ['Circuit Analysis', 'Linear Algebra', 'Python'],
#  'attendance': {'Circuit Analysis': 92,
#   'Linear Algebra': 88,
#   'Python': 96,
#   'Digital Logic': '90'}}

# %%
University_student_record['gpa']
# Out:
# 3.41

# %% [markdown]
# _________________________

# %% [markdown]
# # Task: 3

# %% [markdown]
# 3)  Weather Monitoring Station
# Hourly weather data is stored as a dictionary:
#
# `{   "hour": 14,`<br>
#     `"temperature": 33.8,`<br>
#     `"humidity": 52,`<br>
#     `"wind": {"speed": 12, "direction": "NE"},`<br>
#     `"alerts": []}`<br>
#
# 1.	Print the wind direction.
# 2.	Add a new alert "High Temperature".
# 3.	Change the wind speed to 15.
# 4.	Use .keys() to list all top-level keys.
# 5.	Remove "humidity" using .pop().

# %%
Weather_Monitoring_Station={   "hour": 14,
    "temperature": 33.8,
    "humidity": 52,
    "wind": {"speed": 12, "direction": "NE"},
    "alerts": []}

# %%
Weather_Monitoring_Station['wind']['direction']
# Out:
# 'NE'

# %%
Weather_Monitoring_Station['alerts']='High Temperature'
Weather_Monitoring_Station
# Out:
# {'hour': 14,
#  'temperature': 33.8,
#  'humidity': 52,
#  'wind': {'speed': 12, 'direction': 'NE'},
#  'alerts': 'High Temperature'}

# %%
Weather_Monitoring_Station['wind']['speed']=15
Weather_Monitoring_Station['wind']['speed']
# Out:
# 15

# %%
Weather_Monitoring_Station.keys()
# Out:
# dict_keys(['hour', 'temperature', 'humidity', 'wind', 'alerts'])

# %%
Weather_Monitoring_Station.pop('humidity')
# Out:
# 52

# %%
Weather_Monitoring_Station
# Out:
# {'hour': 14,
#  'temperature': 33.8,
#  'wind': {'speed': 15, 'direction': 'NE'},
#  'alerts': 'High Temperature'}

# %% [markdown]
# ______________________

# %% [markdown]
# # Task: 4
# 4)  Inventory System for Electronics Shop
#
# A shop tracks an item in its inventory:
# {
#     `"item_id": 1042,`<br>
#     `"name": "PWM Solar Charge Controller",`<br>
#     `"stock": 18,`<br>
#     `"price": 2500,`<br>
#     `"features": {"voltage": "12/24V", "current": "20A", "brand": "SolarTech"}`<br>
# `}`
# 1.	Print the brand of the controller.
# 2.	Reduce the stock by 2 and update the dictionary.
# 3.	Add a new feature "warranty": "1 year".
# 4.	Check if "price" exists in the dictionary.
# 5.	Merge another dictionary {"discount": 10} into the inventory item.

# %%
Inventory_System={
    "item_id": 1042,
    "name": "PWM Solar Charge Controller",
    "stock": 18,
    "price": 2500,
    "features": {"voltage": "12/24V", "current": "20A", "brand": "SolarTech"}
}

# %%
Inventory_System['name']
# Out:
# 'PWM Solar Charge Controller'

# %%
Inventory_System['stock']=16
Inventory_System
# Out:
# {'item_id': 1042,
#  'name': 'PWM Solar Charge Controller',
#  'stock': 16,
#  'price': 2500,
#  'features': {'voltage': '12/24V', 'current': '20A', 'brand': 'SolarTech'}}

# %%
Inventory_System['warrenty']='1 year'
Inventory_System
# Out:
# {'item_id': 1042,
#  'name': 'PWM Solar Charge Controller',
#  'stock': 16,
#  'price': 2500,
#  'features': {'voltage': '12/24V', 'current': '20A', 'brand': 'SolarTech'},
#  'warrenty': '1 year'}

# %%
'price' in Inventory_System
# Out:
# True

# %%
Inventory_System['dis']={"discount": 10}
Inventory_System
# Out:
# {'item_id': 1042,
#  'name': 'PWM Solar Charge Controller',
#  'stock': 16,
#  'price': 2500,
#  'features': {'voltage': '12/24V', 'current': '20A', 'brand': 'SolarTech'},
#  'warrenty': '1 year',
#  'dis': {'discount': 10}}

# %% [markdown]
# # Task: 5
# 5)  Hospital Patient Monitoring System
#
# Patient vitals are recorded every 10 minutes:
#
# `{    "id": 907,`<br>
#     `"name": "Faisal",`<br>
#     `"heart_rate": 82,`<br>
#     `"oxygen_level": 97,`<br>
#    ` "medications": {"aspirin": "8AM", "vitamin_D": "12PM"}}`
# 1)	Print the oxygen level.
# 2)	Add a new medication "antibiotic": "6PM".
# 3)	Update heart rate to 78.
# 4)	Get the medication schedule for "insulin" using .get() with default "Not Prescribed".
# 5)	Use .items() to print all key-value pairs.

# %%
Hospital_Monitoring_System={
    "id": 907,
    "name": "Faisal",
    "heart_rate": 82,
    "oxygen_level": 97,
    "medications": {"aspirin": "8AM", "vitamin_D": "12PM"}
}

# %%
Hospital_Monitoring_System['oxygen_level']
# Out:
# 97

# %%
Hospital_Monitoring_System['medications']['antibiotic']='6PM'
Hospital_Monitoring_System
# Out:
# {'id': 907,
#  'name': 'Faisal',
#  'heart_rate': 82,
#  'oxygen_level': 97,
#  'medications': {'aspirin': '8AM', 'vitamin_D': '12PM', 'antibiotic': '6PM'}}

# %%
Hospital_Monitoring_System['heart_rate']=78
Hospital_Monitoring_System
# Out:
# {'id': 907,
#  'name': 'Faisal',
#  'heart_rate': 78,
#  'oxygen_level': 97,
#  'medications': {'aspirin': '8AM', 'vitamin_D': '12PM', 'antibiotic': '6PM'}}

# %%
print(Hospital_Monitoring_System['medications'].get('insuline','Not Prescribed'))
# Out:
# Not Prescribed

# %%
Hospital_Monitoring_System.items()
# Out:
# dict_items([('id', 907), ('name', 'Faisal'), ('heart_rate', 78), ('oxygen_level', 97), ('medications', {'aspirin': '8AM', 'vitamin_D': '12PM', 'antibiotic': '6PM'})])

# %% [markdown]
# _________________________
