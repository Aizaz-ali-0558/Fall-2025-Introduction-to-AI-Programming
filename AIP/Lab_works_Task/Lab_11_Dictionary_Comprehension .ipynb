# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-family: 'Arial Black', Gadget, sans-serif; color: #2c3e50; font-size: 32px; text-shadow: 3px 3px 6px rgba(0, 0, 0, 0.2);">University of Engineering And Technology Peshawar</span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-family: 'Georgia', serif; color: #8e44ad; font-size: 28px;">Jalozai Campus</span>
# </div>
#
# __________________
#
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border: 2px solid #333;
#         border-radius: 15px;
#         background: #ffffff;
#         max-width: 700px;
#         box-shadow: 0 6px 15px rgba(0, 0, 0, 0.1);
#         text-align: center;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 28px;
#             color: #2c3e50;
#             text-transform: uppercase;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#         "
#     >
#         Course Title
#     </h1>
#     <h2
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 24px;
#             color: #34495e;
#             margin-top: 10px;
#         "
#     >
#         Introduction To AI Programming
#     </h2>
# </div
#
# ### 📋 <span style="color: #34495e;">Lab Information</span>
#
# - **Lab No.**: <span style="color: #e74c3c;">11</span>
# - **Lab Title**: <span style="color: #2980b9;">Dictionary Comprehension </span>
#
# ### 🙋‍♂️ <span style="color: #34495e;">Submitted By</span>
#
# - **Name**: <span style="color: #2980b9;">Aizaz Ali</span>
# - **Roll No.**: <span style="color: #e74c3c;">24JZELE0558</span>
# - **Section**: <span style="color: #16a085;">B</span>
#
# ---

# %% [markdown]
# _____________________
# ## **Lab work tasks:**
# ___________________________

# %% [markdown]
# ___________________

# %% [markdown]
# # Task 1:

# %% [markdown]
#  Map Device Names to Their Power Ratings
# 1. Given:
# > - devices = ["Fan", "Light", "AC", "Pump"]
# > - power = [60, 15, 1800, 750]
# > - Create a dict using comprehension:
# > - {"Fan": 60, "Light": 15, ...}

# %%
devices = ["Fan", "Light", "AC", "Pump"]
power = [60, 15, 1800, 750]

# %%
device_power = {d: p for d, p in zip(devices, power)}

print(device_power)
# Out:
# {'Fan': 60, 'Light': 15, 'AC': 1800, 'Pump': 750}

# %% [markdown]
# _______________________

# %% [markdown]
# # Task 2:

# %% [markdown]
# Categorize Resistances as “Low” or “High”
# 1. Given
# >- Resistance values (ohms):
# >- R = [5, 33, 47, 82, 10]
# >- Create a dict:
# >- Key = value, Value = "Low" if R < 40 else "High".

# %%
R = [5, 33, 47, 82, 10]

# %%
# d = {x: x for x in R}  in theis comprehension key = vlaue
Categorize_Resistances={x:('Low' if x<40 else 'high') for x in R}
Categorize_Resistances
# Out:
# {5: 'Low', 33: 'Low', 47: 'high', 82: 'high', 10: 'Low'}

# %% [markdown]
# ____________________

# %% [markdown]
# # Task 3:

# %% [markdown]
# Compute Current for Each Load
# 1. Given
# >- Loads in watts:
# >- loads = [60, 100, 150, 200]
# >- Assume voltage = 200 V
# >- Dictionary comprehension to produce:
# >- {load: load/200} (I = P/V)

# %%
loads = [60, 100, 150, 200]

# %%
Load_in_watt={load:(load/200) for load in loads}
Load_in_watt
# Out:
# {60: 0.3, 100: 0.5, 150: 0.75, 200: 1.0}

# %% [markdown]
# ___________________

# %% [markdown]
# # Task 4:

# %% [markdown]
# Convert Dictionary Values From °C to °F
# - Given:
# >1. temps_c = {"motor": 40, "transformer": 60, "room": 28}
# >2. Use dict comprehension to convert to Fahrenheit.

# %%
temps_c = {"motor": 40, "transformer": 60, "room": 28}
temps_F={k: (v * 9/5) + 32 for k,v in temps_c.items()}
temps_F
# Out:
# {'motor': 104.0, 'transformer': 140.0, 'room': 82.4}

# %% [markdown]
# ________________

# %% [markdown]
# # Task 5:

# %% [markdown]
# Create Dict of Components With Index Keys
# 1. Given component names:
# >- components = ["Resistor", "Capacitor", "Inductor", "Diode"]
# >- Create {0:"Resistor", 1:"Capacitor", ...}
# >- Using dict comprehension + enumerate.

# %%
components = ["Resistor", "Capacitor", "Inductor", "Diode"]

# %%
components_with_index={key:value for key,value in enumerate(components)}
components_with_index
# Out:
# {0: 'Resistor', 1: 'Capacitor', 2: 'Inductor', 3: 'Diode'}

# %% [markdown]
# ____________

# %% [markdown]
# # Task 6:

# %% [markdown]
# Filter Only Devices With Power > 100W
# 1. Given:
# >- device_power = {"Fan": 60, "Light": 15, "Heater": 1200, "Iron": 1000, "Router": 10}
# >- Use dict comprehension to keep only items where value > 100.

# %%
device_power = {"Fan": 60, "Light": 15, "Heater": 1200, "Iron": 1000, "Router": 10}
power_greater_100={key:value for key,value in device_power.items() if value>100}
power_greater_100
# Out:
# {'Heater': 1200, 'Iron': 1000}

# %% [markdown]
# _____________________
