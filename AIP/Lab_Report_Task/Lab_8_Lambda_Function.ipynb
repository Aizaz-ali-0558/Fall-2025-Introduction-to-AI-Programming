# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-family: 'Arial Black', Gadget, sans-serif; color: #2c3e50; font-size: 32px; text-shadow: 3px 3px 6px rgba(0, 0, 0, 0.2);">University of Engineering And Technology Peshawar</span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-family: 'Georgia', serif; color: #8e44ad; font-size: 28px;">Jalozai Campus</span>
# </div>

# %% [markdown]
# ___________

# %% [markdown]
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border: 2px solid #333;
#         border-radius: 15px;
#         background: #ffffff;
#         max-width: 700px;
#         box-shadow: 0 6px 15px rgba(0, 0, 0, 0.1);
#         text-align: center;
#     "
# >
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 28px;
#             color: #2c3e50;
#             text-transform: uppercase;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#         "
#     >
#         Course Title
#     </h1>
#     <h2
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 24px;
#             color: #34495e;
#             margin-top: 10px;
#         "
#     >
#         Introduction To AI Programming
#     </h2>
# </div

# %% [markdown]
# ### 📋 <span style="color: #34495e;">Lab Information</span>
#
# - **Lab No.**: <span style="color: #e74c3c;">8</span>
# - **Lab Title**: <span style="color: #2980b9;">Lambda Function</span>
#
# ### 🙋‍♂️ <span style="color: #34495e;">Submitted By</span>
#
# - **Name**: <span style="color: #2980b9;">Aizaz Ali</span>
# - **Roll No.**: <span style="color: #e74c3c;">24JZELE0558</span>
# - **Section**: <span style="color: #16a085;">B</span>
#
# ---

# %% [markdown]
# _________________
# ## **Lab Report Tasks:**
# _________________

# %% [markdown]
# _______________
# You’re writing small analysis tools for an electrical lab. You need quick one-line functions to calculate adjusted power readings, filter noisy sensor data, sort components by rating, and combine multiple electrical values. Each task builds a specific mini-tool using Python lambda functions.

# %% [markdown]
# ## Task 1
# - Basic lambda for a simple electrical formula
# - Write a lambda that takes a voltage value V and returns V² + 2.
# - Test it with V = 5.
# - (Represents a toy “adjusted voltage metric.”)

# %%
adjusted_voltage_matrix = lambda V: V**2 + 2
print(adjusted_voltage_matrix(5))
# Out:
# 27

# %% [markdown]
# __________

# %% [markdown]
# ## Task 2 — Lambda with two electrical parameters
# Write a lambda that takes two resistances R1 and R2 and returns their equivalent parallel resistance using:
# R_eq=R1*R2/(R1+R2)
# Test it with:
#
#     R1 = 100 Ω
#
#     R2 = 200 Ω

# %%
R_eq = lambda R1, R2: (R1*R2)/(R1+R2)

R_eq(100, 200)
# Out:
# 66.66666666666667

# %% [markdown]
# ____________________________
